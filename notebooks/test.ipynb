# %%
import os
import sys
import warnings

warnings.filterwarnings("ignore")

# Adiciona o diretório raiz do projeto ao Python path
project_root = os.path.abspath("..")
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
import os

from dotenv import load_dotenv
from google import genai

load_dotenv("../src/fundeb_analysis/config/.env")

api_key = os.getenv("GEMINI_API_KEY")

client = genai.Client(api_key=api_key)

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="O que agentes de IA fazem de diferente de uma IA tradicional?",
)

print(response.text)
# Out:
# A diferença principal entre um "agente de IA" e uma "IA tradicional" reside na **autonomia, interação contínua com um ambiente dinâmico e orientação a metas**.
#
# Vamos detalhar:
#
# ---
#
# ### IA Tradicional (ou Modelos de IA Específicos)
#
# Quando falamos em "IA tradicional" ou apenas "IA" de forma genérica, muitas vezes nos referimos a sistemas ou algoritmos que são excelentes em tarefas específicas, mas que operam de forma mais reativa ou sob um controle mais direto.
#
# **Características:**
#
# 1.  **Foco em Tarefas Específicas:** Projetada para resolver um problema bem definido (ex: classificar imagens, traduzir texto, prever resultados).
# 2.  **Modelo Entrada-Saída:** Recebe uma entrada, processa-a e gera uma saída. A interação é pontual.
# 3.  **Ambiente Estático ou Controlado:** Geralmente não interage diretamente com um ambiente dinâmico e em constante mudança. Seus "dados" são pré-definidos ou vêm de fontes controladas.
# ...

# %%
import pandas as pd

URL = "https://www.fnde.gov.br/olinda-ide/servico/DADOS_ABERTOS_SIOPE/versao/v1/odata/Despesas_Funcao_Educacao_Siope(Ano_Consulta=@Ano_Consulta,Num_Peri=@Num_Peri,Sig_UF=@Sig_UF)?@Ano_Consulta=2025&@Num_Peri=4&@Sig_UF='AP'&$top=100&$format=text/csv"

df = pd.read_csv(URL)
# df = df.loc[df.TIPO=="Estadual"]
df.head(20)
# Out:
#          TIPO  NUM_ANO  NUM_PERI  COD_UF SIG_UF  COD_MUNI  NOM_MUNI  NUM_ORDE  \
# 0   Municipal     2025         4      16     AP    160050  Oiapoque         6
# 1   Municipal     2025         4      16     AP    160050  Oiapoque         7
# 2   Municipal     2025         4      16     AP    160050  Oiapoque        11
# 3   Municipal     2025         4      16     AP    160050  Oiapoque        12
# 4   Municipal     2025         4      16     AP    160050  Oiapoque        13
# 5   Municipal     2025         4      16     AP    160050  Oiapoque        14
# 6   Municipal     2025         4      16     AP    160060   Santana         6
# 7   Municipal     2025         4      16     AP    160060   Santana         7
# 8   Municipal     2025         4      16     AP    160060   Santana        11
# 9   Municipal     2025         4      16     AP    160060   Santana        12
# 10  Municipal     2025         4      16     AP    160060   Santana        13
# ...
