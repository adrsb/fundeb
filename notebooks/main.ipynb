# %% [markdown]
# # **IMPORTS/CONFIGURAÇÕES**

# %%
import pandas as pd
from financial.financial_data_visualization import card_chart, financial_transaction_chart, donut_chart, v_bar_chart, h_bar_chart, comparison_card_chart, table_chart, indicator_chart
import warnings
import plotly.graph_objects as go # templates=["plotly", "plotly_white", "plotly_dark", "ggplot2", "seaborn", "simple_white", "none"]
import plotly as px
import datetime


warnings.filterwarnings('ignore')
pd.options.display.float_format = '{:,.2f}'.format
pd.options.display.max_colwidth = None

year = 2025
bi = '3'
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 from financial.financial_data_visualization import card_chart, financial_transaction_chart, donut_chart, v_bar_chart, h_bar_chart, comparison_card_chart, table_chart, indicator_chart
#       3 import warnings
#       4 import plotly.graph_objects as go # templates=["plotly", "plotly_white", "plotly_dark", "ggplot2", "seaborn", "simple_white", "none"]
#
# ModuleNotFoundError: No module named 'financial'

# %% [markdown]
# # **EXTRACTION**

# %% [markdown]
# ## SIOPE

# %%
saldo_inicial_siope = 15778860.40
entradas_siope = 582119339.83
saidas_siope = -465250930.80
saldo_final_siope = 132647269.43
ajustes_positivos_siope = 79521.49
ajustes_negativos_siope = 37935.10
saidas_ajustada_siope = saidas_siope+ajustes_positivos_siope-ajustes_negativos_siope
saldo_final_ajustado_siope = saldo_final_siope+ajustes_positivos_siope-ajustes_negativos_siope

receitas_impostos_siope = 576252613.25
receitas_complemen_vaaf_siope = 0.00
receitas_complemen_vaat_siope = 0.00
receitas_complemen_vaar_siope = 1483974.41
receitas_complemen_siope = receitas_complemen_vaaf_siope+receitas_complemen_vaat_siope+receitas_complemen_vaar_siope
rendimentos_siope = 4382752.17
ressarcimentos_siope = 0.00
receitas_siope = receitas_impostos_siope+receitas_complemen_siope+rendimentos_siope+ressarcimentos_siope

# %%
dotacao_att_fol_pag = 1010887165.00
desp_empenhadas_fol_pag = 489983792.97
desp_liquidadas_fol_pag = 489983792.97
desp_pagas_fol_pag = 446114945.85
desp_rap_fol_pag = 80518.53

dotacao_att_out_desp = 39112835.00
desp_empenhadas_out_desp = 19055466.42
desp_liquidadas_out_desp = 19055466.42
desp_pagas_out_desp = 19055466.42
desp_rap_out_desp = 0.00


dotacao_att = dotacao_att_fol_pag+dotacao_att_out_desp
desp_empenhadas = desp_empenhadas_fol_pag+desp_empenhadas_out_desp
desp_liquidadas = desp_liquidadas_fol_pag+desp_liquidadas_out_desp
desp_pagas = desp_pagas_fol_pag+desp_pagas_out_desp
desp_rap = desp_rap_fol_pag+desp_rap_out_desp


desp_remu_prof_edu_liquidada_ens_fundamental = 144880596.39
desp_remu_prof_edu_liquidada_ens_medio = 345103196.58
desp_remu_prof_edu_liquidada = desp_remu_prof_edu_liquidada_ens_medio+desp_remu_prof_edu_liquidada_ens_fundamental

outras_desp_liquidada_ens_fundamental_corrente = 13338826.49
outras_desp_liquidada_ens_fundamental_capital = 0.00
outras_desp_liquidada_ens_fundamental = outras_desp_liquidada_ens_fundamental_corrente+outras_desp_liquidada_ens_fundamental_capital
outras_desp_liquidada_ens_medio_corrente = 5716639.93
outras_desp_liquidada_ens_medio_capital = 0.00
outras_desp_liquidada_ens_medio = outras_desp_liquidada_ens_medio_corrente+outras_desp_liquidada_ens_medio_capital
outras_desp_liquidada = outras_desp_liquidada_ens_fundamental+outras_desp_liquidada_ens_medio

# %%
minimo_70_exigido = 406436875.52
minimo_70_aplicado = desp_empenhadas_fol_pag
minimo_70_total = minimo_70_exigido/0.7

minimo_30_exigido = minimo_70_exigido/0.7*0.3
minimo_30_aplicado = desp_empenhadas_out_desp
minimo_30_total = minimo_70_exigido/0.7

minimo_50_vaat = 0

minimo_15_vaat_exigido = 0
minimo_15_vaat_aplicado = 0
minimo_15_vaat_total = minimo_15_vaat_exigido/0.15

maximo_10_exigido = 58211933.98
maximo_10_n_aplicado = 73080080.44
maximo_10_total = maximo_10_exigido/0.1

# %% [markdown]
# ### Movimentação Financeira

# %%
fin_df = pd.DataFrame(
    {
        'Descrição': [
            'DISPONIBILIDADE FINANCEIRA EM 31 DE DEZEMBRO DE 2024', 
            '(+) INGRESSO DE RECURSOS ATÉ O BIMESTRE (orçamentário)', 
            '(-) PAGAMENTOS EFETUADOS ATÉ O BIMESTRE (orçamentário e restos a pagar)', 
            '(=) DISPONIBILIDADE FINANCEIRA ATÉ O BIMESTRE', 
            '(+) AJUSTES POSITIVOS (RETENÇÕES E OUTROS VALORES EXTRAORÇAMENTÁRIOS)', 
            '(-) AJUSTES NEGATIVOS (OUTROS VALORES EXTRAORÇAMENTÁRIOS)', 
            '(=) SALDO FINANCEIRO CONCILIADO (Saldo Bancário)'],
        'Valor (R$)': [
            saldo_inicial_siope, 
            entradas_siope, 
            saidas_siope, 
            saldo_final_siope, 
            ajustes_positivos_siope, 
            ajustes_negativos_siope, 
            saldo_final_ajustado_siope]},
)

table_fin_df = table_chart(
    fin_df,
    cell_fill_color=['white','#F9FAFB','white','#EFF6FF','white','#F9FAFB','#EFF6FF'],
    columnwidth=[10,2.5],
    cellheight=25,
    width=600, 
    height=215)
table_fin_df.show()

# table_fin_df.write_image('../2025/Dados_processados/imgs/financeiro/tabelas/movimentação_financeira_siope.png', width=600, height=215)

# %%
ingressos_df = pd.DataFrame(
    {'Repasses ao Fundo': [
        '1- Receitas Recebidas no Exercício',
        '....1.1 - Transferências de Recursos do FUNDEB - Imposto e Transferências',
        '....1.2 - Complementação da União ao FUNDEB',
        '........1.2.1 - VAAF',
        '........1.2.2 - VAAT',
        '........1.2.3 - VAAR',
        '....1.3 - Rendimentos de Aplicação Financeira de Recursos do FUNDEB',
        '....1.4 - Ressarcimento de Recursos do FUNDEB'
    ],
    'Valor (R$)': [
        receitas_siope,
        receitas_impostos_siope,
        receitas_complemen_siope,
        receitas_complemen_vaaf_siope,
        receitas_complemen_vaat_siope,
        receitas_complemen_vaar_siope,
        rendimentos_siope,
        ressarcimentos_siope
    ]
    }
)

table_ingressos_df = table_chart(
    ingressos_df,
    cell_fill_color=['#EFF6FF','#F9FAFB','#F9FAFB','white','white','white','#F9FAFB','#F9FAFB'],
    columnwidth=[10,3],
    cellheight=25,
    width=1200, 
    height=240)
table_ingressos_df.show()
# table_ingressos_df.write_image('../2025/Dados_processados/imgs/financeiro/tabelas/entradas_financeiras_siope.png', width=1200, height=240)

# %%
fin_desp = pd.DataFrame(
    {
        'Descrição': [
            'PAGAMENTOS EFETUADOS ATÉ O BIMESTRE (orçamentário e restos a pagar)', 
            '(+) AJUSTES POSITIVOS (RETENÇÕES E OUTROS VALORES EXTRAORÇAMENTÁRIOS)', 
            '(-) AJUSTES NEGATIVOS (OUTROS VALORES EXTRAORÇAMENTÁRIOS)', 
            '<b>(=) Valor Ajustado</b>'],
        'Valor (R$)': [
            saidas_siope, 
            ajustes_positivos_siope, 
            ajustes_negativos_siope, 
            saidas_ajustada_siope]},
)

table_fin_desp = table_chart(
    fin_desp,
    cell_fill_color=['white','#F9FAFB','white','#EFF6FF'],
    columnwidth=[10,2.5],
    cellheight=25,
    width=600, 
    height=140)
table_fin_desp.show()

# table_fin_desp.write_image('../2025/Dados_processados/imgs/financeiro/tabelas/saidas_financeiras_ajustada_siope.png', width=600, height=140)

# %% [markdown]
# ### Orçamento

# %%
# ----------------------------
# Dados extraídos da sua tabela
# ----------------------------
data = {
    "Fase Orçamentária": [
        "Dotação Atualizada",
        "Despesas Empenhadas",
        "Despesas Liquidadas",
        "Despesas do Exercício Pagas",
        "Despesas Pagas RAP"
    ],
    "TOTAL": [
        dotacao_att,
        desp_empenhadas,
        desp_liquidadas,
        desp_pagas,
        desp_rap
    ]
}

budget_summary_siope = pd.DataFrame(data)
budget_summary_siope

table_budget_summary_siope = table_chart(
    data=budget_summary_siope,
    cell_format=[None,',.2f',',.2f',',.2f'],
    cell_align=['left','right','right','right'],
    cell_fill_color=['white','#F9FAFB']*3+['white']*3,
    columnwidth=[3,1,1,1],
    cellheight=25,
    width=600,
    height=160
)
table_budget_summary_siope.show()
# table_budget_summary_siope.write_image('../2025/Dados_processados/imgs/contabil/tabelas/orçamento_geral_siope.png', width=600, height=160)

# %%
# ----------------------------
# Dados extraídos da sua tabela
# ----------------------------
data = {
    "Fase Orçamentária": [
        "Dotação Atualizada",
        "Despesas Empenhadas",
        "Despesas Liquidadas",
        "Despesas do Exercício Pagas",
        "Despesas Pagas RAP"
    ],
    "Remuneração": [
        dotacao_att_fol_pag,
        desp_empenhadas_fol_pag,
        desp_liquidadas_fol_pag,
        desp_pagas_fol_pag,
        desp_rap_fol_pag
    ],
}

budget_summary_payroll_siope = pd.DataFrame(data)
budget_summary_payroll_siope

table_budget_summary_payroll_siope = table_chart(
    data=budget_summary_payroll_siope,
    cell_format=[None,',.2f',',.2f',',.2f'],
    cell_align=['left','right','right','right'],
    cell_fill_color=['white','#F9FAFB']*3+['white']*3,
    columnwidth=[3,1,1,1],
    cellheight=25,
    width=600,
    height=160
)
table_budget_summary_payroll_siope.show()
# table_budget_summary_payroll_siope.write_image('../2025/Dados_processados/imgs/contabil/tabelas/orçamento_geral_folha_siope.png', width=600, height=160)

# %%
data = {
    "Fase Orçamentária": [
        "Dotação Atualizada",
        "Despesas Empenhadas",
        "Despesas Liquidadas",
        "Despesas do Exercício Pagas",
        "Despesas Pagas RAP"
    ],
    "Outras Despesas": [
        dotacao_att_out_desp,
        desp_empenhadas_out_desp,
        desp_liquidadas_out_desp,
        desp_pagas_out_desp,
        desp_rap_out_desp
    ],
}

budget_summary_others_siope = pd.DataFrame(data)
budget_summary_others_siope

table_budget_summary_others_siope = table_chart(
    data=budget_summary_others_siope,
    cell_format=[None,',.2f',',.2f',',.2f'],
    cell_align=['left','right','right','right'],
    cell_fill_color=['white','#F9FAFB']*3+['white']*3,
    columnwidth=[3,1,1,1],
    cellheight=25,
    width=600,
    height=160
)
table_budget_summary_others_siope.show()
# table_budget_summary_others_siope.write_image('../2025/Dados_processados/imgs/contabil/tabelas/orçamento_geral_outras_desp_siope.png', width=600, height=160)

# %%
saidas_df_siope = pd.DataFrame(
    {'Despesas do Fundo': [
        '1- Remuneração dos Profissionais da Educação Básica',
        '....1.1 - Ensino Fundamental',
        '....1.2 - Ensino Médio',
        '2- Outras Despesas',
        '....2.1 - Ensino Fundamental',
        '........2.1.1 - Corrente',
        '........2.1.2 - Capital',
        '....2.2 - Ensino Médio',
        '........2.2.1 - Corrente',
        '........2.2.2 - Capital'
    ],
    'Valor (R$)': [
        desp_remu_prof_edu_liquidada,
        desp_remu_prof_edu_liquidada_ens_fundamental,
        desp_remu_prof_edu_liquidada_ens_medio,
        outras_desp_liquidada,
        outras_desp_liquidada_ens_fundamental,
        outras_desp_liquidada_ens_fundamental_corrente,
        outras_desp_liquidada_ens_fundamental_capital,
        outras_desp_liquidada_ens_medio,
        outras_desp_liquidada_ens_medio_corrente,
        outras_desp_liquidada_ens_medio_capital
    ]
    }
)

saidas_df_siope
table_saidas_df_siope = table_chart(
    saidas_df_siope,
    cell_fill_color=['#EFF6FF']+['#F9FAFB']*2+['#EFF6FF']+['#F9FAFB','white','white','#F9FAFB','white','white'],
    columnwidth=[10,3],
    cellheight=25,
    width=1200, 
    height=290)
table_saidas_df_siope.show()
# table_saidas_df_siope.write_image('../2025/Dados_processados/imgs/contabil/tabelas/table_saidas_df_siope.png', width=1200, height=290)

# %%
df = saidas_df_siope.copy()
df = df.iloc[[5,6],:]
df

donut_outs_corrent_siope = donut_chart(
    labels=[value[16:] for value in df['Despesas do Fundo']],
    values=df['Valor (R$)'],
    title='Distribuição das Despesas do FUNDEB - SIOPE',
    width=600,
    height=300,
    margin=dict(t=60, b=0, l=10, r=10)
)
donut_outs_corrent_siope.show()
donut_outs_corrent_siope.write_image('../2025/Dados_processados/imgs/siope/graficos/donut_outs_corrent_siope.png', width=600, height=300)
# Out:
# WARNING	Thread(Thread-103 (run)) Task(Task-5) choreographer.browser_async:browser_async.py:_close()- Resorting to unclean kill browser.

# %%
df = saidas_df_siope.copy()
df = df.iloc[[0,3],:]
df

donut_outs_df_siope = donut_chart(
    labels=[value[3:] for value in df['Despesas do Fundo']],
    values=df['Valor (R$)'],
    title='Distribuição das Despesas do FUNDEB - SIOPE',
    width=600,
    height=300,
    margin=dict(t=60, b=0, l=10, r=10)
)
donut_outs_df_siope.show()
# donut_outs_df_siope.write_image('../2025/Dados_processados/imgs/siope/graficos/donut_outs_df_siope.png', width=600, height=300)

# %% [markdown]
# ### Indicadores

# %%
indicators_siope = pd.DataFrame(
    {
    'LIMITES OBRIGATÓRIOS DO FUNDEB': [
        '1. Mínimo de 70% - Remuneração dos Profissionais da Educação Básica',
        '....1.1. Exigido (70% excluídos complementações e seus rendimentos)',
        '....1.2. Aplicado após deduções (Despesas Liquidadas)',
        '2. Máximo de 30%  - Outras Despesas',
        '....2.1. Exigido (30% excluídos complementação da união – VAAR)',
        '....2.2. Aplicado após deduções (despesas liquidadas)',
        '3. Proporção de 50% - Complementação da União ao FUNDEB (VAAT) - Educação Infantil (EXCLUSIVO DF)',
        '4. Mínimo de 15% - Complementação da União ao FUNDEB (VAAT) - Despesas de Capital',
        '....4.1. Exigido (15%)',
        '....4.2. Aplicado após deduções (Empenho)',
        '5. Máximo de 10% - Receitas do Fundeb não Aplicadas no Exercício',
        '....5.1. Exigido (10% do total de receitas registradas no SIOPE)',
        '....5.2. Não aplicado após ajustes (Dedução despesas empenhadas)'
    ],
    'VALORES (R$)': [
        minimo_70_total,
        minimo_70_exigido,
        minimo_70_aplicado,
        minimo_30_total,
        minimo_30_exigido,
        minimo_30_aplicado,
        minimo_50_vaat,
        minimo_15_vaat_total,
        minimo_15_vaat_exigido,
        minimo_15_vaat_aplicado,
        maximo_10_total,
        maximo_10_exigido,
        maximo_10_n_aplicado,
    ],
    '%': [
        100,
        70,
        round(minimo_70_aplicado/minimo_70_total*100, 2),
        100,
        30,
        round(minimo_30_aplicado/minimo_30_total*100, 2),
        100,
        100,
        15,
        0,
        100,
        10,
        round((maximo_10_n_aplicado/maximo_10_total)*100, 2)
    ]
})



table_indicators_siope = table_chart(
    indicators_siope,
    cell_fill_color=['#EFF6FF','white','#F9FAFB']*2+['#EFF6FF']*2+['white','#F9FAFB']+['#EFF6FF']+['white','#F9FAFB'],
    columnwidth=[10,2,1],
    cellheight=25,
    width=1200, 
    height=380)

table_indicators_siope.show()
table_indicators_siope.write_image('../2025/Dados_processados/imgs/siope/tabelas/table_indicators_siope.png', width=1200, height=370)
# Out:
# WARNING	Thread(Thread-115 (run)) Task(Task-115) choreographer.browser_async:browser_async.py:_close()- Resorting to unclean kill browser.

# %% [markdown]
# ## EXTRATOS BANCÁRIOS

# %% [markdown]
# ### Conta Corrente

# %%
from banks_utils import banks_consolidation


consolidation_banks_data = banks_consolidation(
    path_banks=f'../{year}/Dados_fonte/Extratos/Conta_corrente', 
    path_applications=f'../{year}/Dados_fonte/Extratos/Rendimentos', 
    opening_balance=15778860.39,
    type_banks_data='pdf',
    type_applications='pdf', 
    year=2025)
consolidation_banks_data.tail()
# Out:
# WARNING	Task(Task-3) tabula.backend:backend.py:__init__()- Failed to import jpype dependencies. Fallback to subprocess.
# WARNING	Task(Task-3) tabula.backend:backend.py:__init__()- No module named 'jpype'
#             AG_O                  DOC   LOTE COD_HIST  \
# DATA
# 2025-06-30  0000                    0  00000      000
# 2025-06-30  0000                  350  14011      952
# 2025-06-30  0000                  350  14011      952
# 2025-06-30  0000                  350  14011      953
# 2025-06-30  0000  871.811.100.185.728  13113      170
#
#                                 HIST VALOR_APP      VALOR INF          SALDO  \
# DATA
# 2025-06-30               RENDIMENTOS         0 972,555.20   C 131,778,306.83
# 2025-06-30                   FPE/FPM      0.00 895,611.60   C 132,673,918.43
# 2025-06-30                   FPE/FPM      0.00  10,536.57   C 132,684,455.00
# 2025-06-30            IPI/EXPORTACAO      0.00   4,415.05   C 132,688,870.05
# ...

# %% [markdown]
# ### Conta de Aplicações

# %%
from banks_utils import read_pdf_applications

applications = read_pdf_applications(path='../2025/Dados_fonte/Extratos/Rendimentos')
applications
# Out:
#             AG_O   LOTE COD_HIST         HIST DOC VALOR_APP        VALOR INF  \
# DATA
# 2025-01-31  0000  00000      000  RENDIMENTOS   0         0   251,992.13   C
# 2025-02-28  0000  00000      000  RENDIMENTOS   0         0   649,670.60   C
# 2025-03-31  0000  00000      000  RENDIMENTOS   0         0   663,914.50   C
# 2025-04-30  0000  00000      000  RENDIMENTOS   0         0   774,482.43   C
# 2025-05-31  0000  00000      000  RENDIMENTOS   0         0 1,070,137.31   C
# 2025-06-30  0000  00000      000  RENDIMENTOS   0         0   972,555.20   C
#
#             SALDO     DET_HIST
# DATA
# 2025-01-31   0.00  RENDIMENTOS
# 2025-02-28   0.00  RENDIMENTOS
# 2025-03-31   0.00  RENDIMENTOS
# 2025-04-30   0.00  RENDIMENTOS
# 2025-05-31   0.00  RENDIMENTOS
# 2025-06-30   0.00  RENDIMENTOS

# %% [markdown]
# ## REPASSES FNDE

# %% [markdown]
# ### Download

# %%
from yield_utils import download_yield_data


# download_yield_data(2025)

# %% [markdown]
# ### Dados

# %%
from yield_utils import transform_yield_data


transfers_data, transfers_adjust_data = transform_yield_data(2025)
display(transfers_data)
display(transfers_adjust_data)
# Out:
#                      E_FPE         E_FPM      E_IPI    E_ITR E_COUN_VAAF  \
# COMPETÊNCIA
# 01/2025      65,959,887.71  8,192,778.26  21,797.28 1,452.04           0
# 02/2025      86,477,361.52 10,993,762.57  24,674.64     1324           0
# 03/2025      57,360,184.62  7,239,898.27  26,871.47   640.43           0
# 04/2025      58,560,867.71       7356972  25,229.15   439.44           0
# 05/2025      74,446,848.46  9,384,861.14  24,510.65 1,790.36           0
# 06/2025      75,496,214.89  9,639,541.81  27,903.43   409.42           0
# TOTAL       418,301,364.91 52,807,814.05 150,986.62 6,055.69           0
#
#             E_COUN_VAAT  E_COUN_VAAR        E_ICMS        E_IPVA    E_ITCMD  \
# COMPETÊNCIA
# 01/2025               0 1,313,236.08 17,391,684.67     34,348.74  20,855.66
# 02/2025               0            0 12,205,256.42  1,721,670.19 104,850.78
# 03/2025               0            0 14,909,966.49  4,219,366.51          0
# ...

# %% [markdown]
# ## CONCILIAÇÃO BANCÁRIA

# %% [markdown]
# ## SIAFE

# %% [markdown]
# ### Orçamento

# %%
from accounting_utils import accounting_seed_data


accounting_data = accounting_seed_data(path=r'..\2025\Dados_fonte\Contábil\Demonstrativo da Execução Financeira por Credor -( FUNDEB ).xls', bi=bi)
accounting_data.head()
# Out:
#                                  Unidade Gestora / Unidade Orçamentária / Ação  \
# 2        2214 - REMUNERAÇÃO E ENCARGOS DOS PROFISSIONAIS DO ENSINO FUNDAMENTAL
# 3        2214 - REMUNERAÇÃO E ENCARGOS DOS PROFISSIONAIS DO ENSINO FUNDAMENTAL
# 4        2214 - REMUNERAÇÃO E ENCARGOS DOS PROFISSIONAIS DO ENSINO FUNDAMENTAL
# 5        2214 - REMUNERAÇÃO E ENCARGOS DOS PROFISSIONAIS DO ENSINO FUNDAMENTAL
# 6        2214 - REMUNERAÇÃO E ENCARGOS DOS PROFISSIONAIS DO ENSINO FUNDAMENTAL
#
#                                                  Natureza  \
# 2  319011 - Vencimentos e Vantagens Fixas - Pessoal Civil
# 3  319011 - Vencimentos e Vantagens Fixas - Pessoal Civil
# 4  319011 - Vencimentos e Vantagens Fixas - Pessoal Civil
# 5  319011 - Vencimentos e Vantagens Fixas - Pessoal Civil
# 6  319011 - Vencimentos e Vantagens Fixas - Pessoal Civil
#
#                                                                     Fonte  \
# ...

# %% [markdown]
# ### Pagamentos

# %%
from accounting_utils import monthly_accounting_seed_data

monthly_accounting_payments_data = monthly_accounting_seed_data(path=f'../{year}/Dados_fonte/Contábil/Demonstrativo da Execução Financeira por Credor por mês- FUNDEB.xls')
monthly_accounting_payments_data.head()
# Out:
#                                  Unidade Gestora / Unidade Orçamentária / Ação  \
# 2        2214 - REMUNERAÇÃO E ENCARGOS DOS PROFISSIONAIS DO ENSINO FUNDAMENTAL
# 3        2214 - REMUNERAÇÃO E ENCARGOS DOS PROFISSIONAIS DO ENSINO FUNDAMENTAL
# 4        2214 - REMUNERAÇÃO E ENCARGOS DOS PROFISSIONAIS DO ENSINO FUNDAMENTAL
# 5        2214 - REMUNERAÇÃO E ENCARGOS DOS PROFISSIONAIS DO ENSINO FUNDAMENTAL
# 6        2214 - REMUNERAÇÃO E ENCARGOS DOS PROFISSIONAIS DO ENSINO FUNDAMENTAL
#
#                                                  Natureza  \
# 2  319011 - Vencimentos e Vantagens Fixas - Pessoal Civil
# 3  319011 - Vencimentos e Vantagens Fixas - Pessoal Civil
# 4  319011 - Vencimentos e Vantagens Fixas - Pessoal Civil
# 5  319011 - Vencimentos e Vantagens Fixas - Pessoal Civil
# 6  319011 - Vencimentos e Vantagens Fixas - Pessoal Civil
#
#                                                                     Fonte  \
# ...

# %% [markdown]
# ### REs

# %%
from banks_utils import re_consolidation


res_consolidation_data = re_consolidation(f'../{year}/Dados_fonte/Extratos/RE - Resgistros de Envios')
res_consolidation_data.head()
# Out:
#             RE           OB  Tipo              CNPJ/CPF  \
# 0  2025RE00014  2025OB00276 31.00    394,577,000,125.00
# 1  2025RE00014  2025OB00277 32.00             26,158.00
# 2  2025RE00014  2025OB00278 31.00 61,573,796,000,166.00
# 3  2025RE00014  2025OB00279 32.00 37,880,010,000,179.00
# 4  2025RE00014  2025OB00280 31.00    759,231,000,183.00
#
#                                      Favorecido C/C Origem  Banco      Ag.  \
# 0                    GOVERNO DO ESTADO DO AMAPA      79332 104.00   658.00
# 1                           BANCO DO BRASIL S/A      79332   1.00 3,575.00
# 2                           ALLIANZ SEGUROS S.A      79332 237.00 3,114.00
# 3                              ASPA MENSALIDADE      79332   1.00 1,610.00
# 4  ASPBRAS-ASSOC.DOS SERV.PUBLICOS BRASILEIROS.      79332  33.00 2,136.00
#
#              C/C        Valor Cancelamento
# 0     999,994.00 3,384,838.67         <NA>
# 1 310,270,057.00 8,576,713.27         <NA>
# 2   1,396,463.00        19.58         <NA>
# ...

# %% [markdown]
# ## FOLHA DE PAGAMENTO

# %% [markdown]
# ### Dados

# %%
from payroll_utils import dict_cargos, dict_lotacao, get_payroll_data


payroll_data = get_payroll_data(path=f'../{year}/Dados_fonte/Folha_pagamento', dict_cargos=dict_cargos, dict_lotacao=dict_lotacao, bi=int(bi))
payroll_data.head()
# Out:
#                               level_0  level_1     Matrícula  \
# 0  01-2025-Férias-Normal-01-2025.xlsx        0  0041869-2-01
# 1  01-2025-Férias-Normal-01-2025.xlsx        2  0061274-0-01
# 2  01-2025-Férias-Normal-01-2025.xlsx        3  0098092-7-01
# 3  01-2025-Férias-Normal-01-2025.xlsx        4  0041488-3-01
# 4  01-2025-Férias-Normal-01-2025.xlsx        6  0113814-6-01
#
#                                  Nome  \
# 0           ABDIAS RODRIGUES FERREIRA
# 1          ABDINEL RODRIGUES FERREIRA
# 2    ABDORAL BARBOSA DE OLIVEIRA NETO
# 3  ABGAIL DOS SANTOS NASCIMENTO BRUNO
# 4              ABIMAEL BARBOSA CHAGAS
#
#                            Unidade Organizacional                      Cargo  \
# 0  E. E. PROFª MARIA DE NAZARE RODRIGUES DA SILVA  PROFESSOR CLASSE C2 -40HS
# 1                   E. E. ANTONIO CORDEIRO PONTES  PROFESSOR CLASSE C2 -40HS
# 2          E. E. PROFª DENISE DE MELO VASCONCELOS   PROFESSOR CLASSE A1-40HS
# ...

# %% [markdown]
# ### Testes

# %%
from payroll_utils import occupation_test

occupation_test(payroll_data=payroll_data)
# Out:
# []

# %%
from payroll_utils import workplace_test

workplace_test(payroll_data=payroll_data)
# Out:
# []

# %% [markdown]
# # **TRANSFORMATION**

# %% [markdown]
# ## EXTRATOS BANCÁRIOS

# %% [markdown]
# ### Relatório Financeiro Geral

# %%
from banks_utils import banks_summary


bank_statement_summary = banks_summary(consolidation_banks_data, year=2025, periods=12).iloc[:-3].reset_index()
bank_statement_summary.columns = ['Descrição', 'Valor (R$)']
bank_statement_summary = bank_statement_summary.loc[~(bank_statement_summary['Valor (R$)']=='')]

table_bank_statement_summary = table_chart(
    bank_statement_summary,
    cell_fill_color=['white','#F9FAFB']*len(bank_statement_summary),
    columnwidth=[10,3],
    cellheight=25,
    width=1200, 
    height=620)
table_bank_statement_summary.show()

# table_bank_statement_summary.write_image('../2025/Dados_processados/imgs/financeiro/tabelas/movimentação_financeira_extratos.png', width=1200, height=620)

# %% [markdown]
# ### Resumo Movimentação Financeira

# %%
financial_sumary = bank_statement_summary.iloc[[0,1,17,-1], :]
financial_sumary

table_financial_sumary = table_chart(
    financial_sumary,
    cell_fill_color=['#EFF6FF']+['white','#F9FAFB']*len(bank_statement_summary),
    columnwidth=[10,3],
    cellheight=25,
    width=1200, 
    height=140)

table_financial_sumary.show()
# table_financial_sumary.write_image('../2025/Dados_processados/imgs/financeiro/tabelas/resumo_movimentação_financeira.png', width=1200, height=160)

# %% [markdown]
# ### Resumo das Entradas Correntes

# %%
current_ins = bank_statement_summary.iloc[[2,3,6,7,8,9,10,11]]
current_ins

table_current_ins = table_chart(
    current_ins,
    cell_fill_color=['#EFF6FF','#F9FAFB','#F9FAFB','white','white','white','white','#F9FAFB'],
    columnwidth=[10,3],
    cellheight=25,
    width=600, 
    height=240)

table_current_ins.show()
# table_current_ins.write_image('../2025/Dados_processados/imgs/financeiro/tabelas/resumo_entradas_correntes.png', width=600, height=240)

# %% [markdown]
# ### Resumo de Outras Entradas

# %%
other_ins = bank_statement_summary.iloc[[12,13,14,15,16], :]
other_ins

table_other_ins = table_chart(
    other_ins,
    cell_fill_color=['#EFF6FF']+['white','#F9FAFB']*len(bank_statement_summary),
    columnwidth=[10,3],
    cellheight=25,
    width=1200, 
    height=160)

table_other_ins.show()
# table_other_ins.write_image('../2025/Dados_processados/imgs/financeiro/tabelas/resumo_outras_entradas.png', width=600, height=240)

# %% [markdown]
# ### Histórico Bancário - Entradas

# %%
from banks_utils import ins_bank_summary


ins_bank = ins_bank_summary(consolidation_banks_data)
ins_bank
# Out:
# HIST
# FPE/FPM                   471,109,178.96
# RECEBIMENTO DE ICMS        94,440,721.51
# IPVA                       10,361,154.07
# RENDIMENTOS                 4,382,752.17
# VAAR Complemento FUNDEB     1,648,620.10
# IPI/EXPORTACAO                411,241.08
# ITCMD                         184,516.40
# ITR                             6,055.69
# ORDEM BANC CANCELADA              534.15
# TOTAL                     582,544,774.13
# Name: VALOR, dtype: float64

# %% [markdown]
# ### Histórico Bancário - Saídas

# %%
from banks_utils import outs_bank_summary


outs_bank = outs_bank_summary(consolidation_banks_data)
outs_bank
# Out:
# HIST
# Folha de Pagamento          -255,886,216.43
# Emissão Ordem Bancária      -208,609,814.45
# TED Transf.Eletr.Disponiv       -422,195.22
# COTA DAF-DEBITO                 -260,254.46
# Ajuste Complemento VAAR         -164,645.69
# Impostos                        -150,593.16
# Pagamentos Diversos             -130,195.57
# Tar Lib/Ant Float Pg Div          -7,525.91
# Pagto via Auto-Atend.BB           -3,337.80
# TOTAL                       -465,634,778.69
# Name: VALOR, dtype: float64

# %% [markdown]
# ### Ajustes das Saídas Financeiras

# %%
out_bank_calc = outs_bank.copy()
out_bank_calc['Cota DAF'] = -outs_bank['COTA DAF-DEBITO']
out_bank_calc['Ajuste Complementação da União- VAAR'] = -outs_bank['Ajuste Complemento VAAR']
out_bank_calc['Despesas Canceladas/Anuladas'] = ins_bank['ORDEM BANC CANCELADA']
out_bank_calc['TOTAL AJUSTADO'] = outs_bank['TOTAL']-outs_bank['COTA DAF-DEBITO']-outs_bank['Ajuste Complemento VAAR']+ins_bank['ORDEM BANC CANCELADA']
out_bank_calc = out_bank_calc.reset_index()
out_bank_calc.columns = ['Histórico Bancário', 'Montante (R$)']
out_bank_calc

table_out_bank_calc = table_chart(
    data=out_bank_calc,
    cell_fill_color=['white','#F9FAFB']*4+['white','#EFF6FF']+['white','#F9FAFB', 'white','#EFF6FF'],
    columnwidth=[10,3],
    cellheight=25,
    width=1200,
    height=390,
)
table_out_bank_calc.show()
# table_out_bank_calc.write_image('../2025/Dados_processados/imgs/financeiro/tabelas/tab_calc_total_ajustado_desp.png', width=1200, height=390)

# %% [markdown]
# ## REPASSES FNDE

# %%
from yield_utils import yield_summary


incomes_summary = yield_summary(transfers_data, transfers_adjust_data)
incomes_summary
# Out:
#             TOTAL_REPASSES TOTAL_AJUSTES TOTAL_REPASSES_LIQUIDO  \
# COMPETÊNCIA
# 01/2025      93,100,686.13   -164,645.69          92,936,040.44
# 02/2025     111,528,900.12             0         111,528,900.12
# 03/2025      83,756,927.79             0          83,756,927.79
# 04/2025      82,197,614.72             0          82,197,614.72
# 05/2025     104,109,388.73             0         104,109,388.73
# 06/2025     103,207,715.86             0         103,207,715.86
# TOTAL       577,901,233.35   -164,645.69         577,736,587.66
#
#             TOTAL_REPASSES_LIQUIDO_ACUMULADO
# COMPETÊNCIA
# 01/2025                        92,936,040.44
# 02/2025                       204,464,940.56
# 03/2025                       288,221,868.35
# 04/2025                       370,419,483.07
# 05/2025                       474,528,871.80
# 06/2025                       577,736,587.66
# TOTAL                         577,736,587.66

# %% [markdown]
# ## SIAFE

# %% [markdown]
# ### Orçamento Geral

# %%
from accounting_utils import budget_seed_summary


total_budget_summary = budget_seed_summary(accounting_data)[['Ordem','Fase Orçamentária','TOTAL']]

table_total_budget_summary = table_chart(
    data=total_budget_summary,
    cell_format=[None, None,',.2f'],
    cell_align=['left','left','right'],
    cell_fill_color=['white','#F9FAFB']*3+['white']*3,
    columnwidth=[0.7,3,2,1,1],
    cellheight=25,
    width=600,
    height=260
)
table_total_budget_summary.show()
# table_total_budget_summary.write_image('../2025/Dados_processados/imgs/contabil/tabelas/orçamento_total_geral_siafe.png', width=600, height=260)

# %%
df = total_budget_summary.copy()
df = df.iloc[1:6,:]
# ----------------------------
# 1. Gráfico de Barras Empilhadas
# ----------------------------
v_bar_total_budget_summary = v_bar_chart(
    x=df['Fase Orçamentária'],
    y=df['TOTAL'],
    title='Resumo do Orçamento Anual - FUNDEB',
    width=1200,
    height=600,
    color=px.colors.sequential.Plasma_r
)
v_bar_total_budget_summary.show()
v_bar_total_budget_summary.write_image('../2025/Dados_processados/imgs/contabil/graficos/v_bar_total_budget_summary.png', width=1200, height=600)
# Out:
# WARNING	Thread(Thread-84 (run)) Task(Task-120) choreographer.browser_async:browser_async.py:_close()- Resorting to unclean kill browser.

# %%
from accounting_utils import budget_seed_summary


payroll_budget_summary = budget_seed_summary(accounting_data)[['Ordem','Fase Orçamentária','Despesas com Remuneração dos Profissionais da Educação Básica']]

table_payroll_budget_summary = table_chart(
    data=payroll_budget_summary,
    cell_format=[None, None,',.2f'],
    cell_align=['left','left','right'],
    cell_fill_color=['white','#F9FAFB']*3+['white']*3,
    columnwidth=[0.7,3,2,1,1],
    cellheight=25,
    width=600,
    height=300
)
table_payroll_budget_summary.show()
# table_payroll_budget_summary.write_image('../2025/Dados_processados/imgs/contabil/tabelas/orçamento_folha_siafe.png', width=600, height=300)
# Out:
# WARNING	Thread(Thread-87 (run)) Task(Task-157) choreographer.browser_async:browser_async.py:_close()- Resorting to unclean kill browser.

# %%
df = payroll_budget_summary.copy()
df = df.iloc[1:6,:]
# ----------------------------
# 1. Gráfico de Barras Empilhadas
# ----------------------------
v_bar_payroll_budget_summary = v_bar_chart(
    x=df['Fase Orçamentária'],
    y=df['Despesas com Remuneração dos Profissionais da Educação Básica'],
    title='Resumo do Orçamento Anual de Despesas com Remuneração dos Profissionais da Educação Básica Pública - FUNDEB',
    width=1200,
    height=600,
    color=px.colors.sequential.Plasma_r
)
v_bar_payroll_budget_summary.show()
# v_bar_payroll_budget_summary.write_image('../2025/Dados_processados/imgs/contabil/graficos/v_bar_payroll_budget_summary.png', width=1200, height=600)
# Out:
# WARNING	Thread(Thread-89 (run)) Task(Task-194) choreographer.browser_async:browser_async.py:_close()- Resorting to unclean kill browser.

# %%
from accounting_utils import budget_seed_summary


others_outs_budget_summary = budget_seed_summary(accounting_data)[['Ordem','Fase Orçamentária','Outras Despesas']]

table_others_outs_budget_summary = table_chart(
    data=others_outs_budget_summary,
    cell_format=[None, None,',.2f'],
    cell_align=['left','left','right'],
    cell_fill_color=['white','#F9FAFB']*3+['white']*3,
    columnwidth=[0.7,3,2,1,1],
    cellheight=25,
    width=600,
    height=260
)
table_others_outs_budget_summary
# table_others_outs_budget_summary.write_image('../2025/Dados_processados/imgs/contabil/tabelas/orçamento_geral.png', width=1200, height=310)

# %%
df = others_outs_budget_summary.copy()
df = df.iloc[1:6,:]
# ----------------------------
# 1. Gráfico de Barras Empilhadas
# ----------------------------
v_bar_other_outs_budget_summary = v_bar_chart(
    x=df['Fase Orçamentária'],
    y=df['Outras Despesas'],
    title='Resumo do Orçamento Anual com Outras Despesas - FUNDEB',
    width=1200,
    height=600,
    color=px.colors.sequential.Plasma_r
)
v_bar_other_outs_budget_summary.show()
# v_bar_other_outs_budget_summary.write_image('../2025/Dados_processados/imgs/contabil/graficos/v_bar_other_outs_budget_summary.png', width=1200, height=600)
# Out:
# WARNING	Thread(Thread-92 (run)) Task(Task-231) choreographer.browser_async:browser_async.py:_close()- Resorting to unclean kill browser.

# %%
budget_summary = budget_seed_summary(accounting_data)
table_total_budget_summary = table_chart(
    data=budget_summary,
    cell_format=[None, None,',.2f'],
    cell_align=['left','left','right'],
    cell_fill_color=['white','#F9FAFB']*3+['white']*3,
    columnwidth=[0.7,3,2,1,1],
    cellheight=25,
    width=600,
    height=260
)
table_total_budget_summary.show()

# %% [markdown]
# ### Orçamento Detalhado da Folha

# %%
from accounting_utils import payroll_seed_budget



payroll_budget = payroll_seed_budget(accounting_data)
payroll_budget = payroll_budget.reset_index(level=[1,2])
table_payroll_budget = table_chart(
    data=payroll_budget,
    cell_format=['center', 'center',',.2f',',.2f',',.2f'],
    cell_align=['left']*2+['right']*8,
    cell_fill_color=['white','#F9FAFB']*2+['white','#EFF6FF'],
    columnwidth=[4,3,1,1,1,1,1,1,1,1],
    cellheight=25,
    width=1200,
    height=260
)
table_payroll_budget.show()
# table_payroll_budget.write_image('../2025/Dados_processados/imgs/contabil/tabelas/oraçamento_folha_detalhado.png',width=1200,height=260)

# %% [markdown]
# ### Orçamento Detalhado de Outras Despesas

# %%
from accounting_utils import other_expenses_seed_budget

other_expenses_budget = other_expenses_seed_budget(accounting_data)
other_expenses_budget = other_expenses_budget.reset_index(level=[1,2])
table_other_expenses_budget = table_chart(
    data=other_expenses_budget,
    cell_format=['center', 'center',',.2f'],
    cell_align=['left']*2+['right']*8,
    cell_fill_color=['white','#EFF6FF'],
    columnwidth=[2,2,1,1,1,1,1,1,1,1],
    cellheight=25,
    width=1200,
    height=170
)
table_other_expenses_budget.show()
# table_other_expenses_budget.write_image('../2025/Dados_processados/imgs/contabil/tabelas/oraçamento_outras_despesas_detalhado.png',width=1200,height=150)

# %% [markdown]
# ### Orçamento Detalhado - Total

# %%
from accounting_utils import accounting_seed_summary


accounting_summary = accounting_seed_summary(accounting_data)
accounting_summary = accounting_summary.iloc[-1,:].to_frame().T
table_accounting_summary = table_chart(
    data=accounting_summary,
    cell_format=['center', 'center',',.2f',',.2f',',.2f'],
    cell_align=['left']*2+['right']*8,
    cell_fill_color=['#EFF6FF'],
    # columnwidth=[10,3],
    cellheight=25,
    width=1200,
    height=100
)
table_accounting_summary.show()
# table_accounting_summary.write_image('../2025/Dados_processados/imgs/contabil/tabelas/oraçamento_detalhado_total.png',width=1200,height=100)

# %% [markdown]
# ### Processos Pagos

# %%
paid_cases = accounting_data.loc[(accounting_data['Natureza']=='339039 - Outros Serviços de Terceiros - Pessoa Jurídica ') & ((accounting_data['Despesas do Exercício Pagas']!=0) | (accounting_data['Despesas Pagas RAP']!=0))].sort_values(by=['Credor', 'OB'])
paid_cases
table_paid_cases = table_chart(
    data=paid_cases,
    cell_format=['center']*8 + [',.2f']*9 + ['center'],
    cell_align=['left']*8+['right'],
    cell_fill_color=['#EFF6FF'],
    # columnwidth=[10,3],
    cellheight=25,
    width=1200,
    height=200
)
table_paid_cases.show()

# %% [markdown]
# ### REs

# %%
res_canceled = res_consolidation_data.loc[~res_consolidation_data.Cancelamento.isna()]
total = pd.DataFrame(data={
    'RE':['<b>TOTAL</b>'],
    'OB':[''],
    'Tipo':[''],
    'CNPJ/CPF':[''],
    'Favorecido':[''],
    'C/C Origem':[''],
    'Banco':[''],
    'Ag.':[''],
    'C/C':[''],
    'Valor':[round(res_canceled.Valor.sum(),2)],
    'Cancelamento':['']})
total
res_canceled= pd.concat([res_canceled, total])
res_canceled=res_canceled[['RE','OB','CNPJ/CPF','Favorecido','Valor','Cancelamento']]

table_res_canceled = table_chart(
    res_canceled,
    cell_format=[None,None,None,None,None,None,None,None,None,',.2f',None],
    cell_align=['center','center','center','center','center','center','center','center','center','right','center'],
    cell_fill_color=['white', '#F9FAFB']*2+['white','#EFF6FF'],
    # columnwidth=[10,3],
    cellheight=25,
    width=1200,
    height=190
)
table_res_canceled.show()
# table_res_canceled.write_image('../2025/Dados_processados/imgs/contabil/tabelas/res_canceladas.png', width=1200, height=190)

# %% [markdown]
# ## FOLHA DE PAGAMENTO

# %% [markdown]
# ### Folhas de Pagamento

# %%
from payroll_utils import payrolls_summary


payroll_summary = payrolls_summary(payroll_data)
payroll_summary = payroll_summary.reset_index()
payroll_summary

table_payroll_summary = table_chart(
    payroll_summary,
    cell_format=[None,None,None,None,',.2f'],
    cell_align=['center','center','center','center','right'],
    cell_fill_color=['white', '#F9FAFB']*5,
    columnwidth=[1,1,1,1,1,1,1.5],
    cellheight=25,
    width=1200,
    height=270
)
table_payroll_summary.show()
table_payroll_summary.write_image('../2025/Dados_processados/imgs/folha/tabelas/folha_pagamento_arquivo.png', width=1200, height=270)
# Out:
# WARNING	Thread(Thread-63 (run)) Task(Task-190) choreographer.browser_async:browser_async.py:_close()- Resorting to unclean kill browser.

# %% [markdown]
# ### Folhas de Pagamento Mensais

# %%
from payroll_utils import payrolls_summary, monthly_payroll_summary


payroll_summary = payrolls_summary(payroll_data)
monthly_summary = monthly_payroll_summary(payroll_summary)
monthly_summary = monthly_summary.reset_index()
monthly_summary.rename(axis=1, mapper={'Competência': 'COMPETÊNCIA'}, inplace=True)

table_monthly_summary = table_chart(
    monthly_summary,
    cell_format=[None,',.2f'],
    cell_align=['center','right'],
    cell_fill_color=['white', '#F9FAFB']*3,
    # columnwidth=[1,3,1,1,],
    cellheight=25,
    width=1200,
    height=190
)
table_monthly_summary.show()
# table_monthly_summary.write_image('../2025/Dados_processados/imgs/folha/tabelas/folha_pagamento_mes.png', width=1200, height=190)

# %%
data = monthly_summary.copy()
data

v_bar_monthly_summary = v_bar_chart(
    x=data['COMPETÊNCIA'],
    y=data['VALOR'],
    title='Folha de Pagamento Mensal',
    width=600,
    height=300
    )
v_bar_monthly_summary.show()
v_bar_monthly_summary.write_image('../2025/Dados_processados/imgs/folha/v_bar_monthly_summary.png', width=600, height=300)
# Out:
# WARNING	Thread(Thread-229 (run)) Task(Task-601) choreographer.browser_async:browser_async.py:_close()- Resorting to unclean kill browser.

# %%
data = monthly_summary.copy()
data

v_bar_monthly_summary = v_bar_chart(
    x=data['COMPETÊNCIA'],
    y=data['TOTAL_ACUMULADO'],
    title='Folha de Pagamento Mensal Acumulado',
    width=600,
    height=300
    )
v_bar_monthly_summary.show()
v_bar_monthly_summary.write_image('../2025/Dados_processados/imgs/folha/v_bar_monthly_summary_cumulative.png', width=600, height=300)
# Out:
# WARNING	Thread(Thread-231 (run)) Task(Task-638) choreographer.browser_async:browser_async.py:_close()- Resorting to unclean kill browser.

# %% [markdown]
# ### Folha de Pagamento por Cargos

# %%
from payroll_utils import categorical_payroll_summary


occupations_financial_summary = categorical_payroll_summary(payroll_data, mode='financial', category='cargo')
occupations_financial_summary
# Out:
#                        CARGO       01-2025       02-2025       03-2025  \
# 0    AUXILIAR ADMINISTRATIVO    481,122.43    476,393.86    467,123.02
# 1       AUXILIAR EDUCACIONAL    486,480.64    487,773.11    478,116.19
# 2                   CUIDADOR    688,437.70    809,010.62    809,010.64
# 3                    DIRETOR  2,213,181.75  2,173,917.12  2,181,644.65
# 4   ESPECIALISTA EM EDUCAÇÃO    514,059.36    445,258.01    445,794.42
# 5                    GERENTE      6,929.69     18,928.53     31,236.67
# 6       GRATIFICAÇÃO DESTINO          0.00          0.00      3,600.00
# 7                  INSTRUTOR     57,784.02     43,963.03     43,963.03
# 8       INTERPRETE DE LIBRAS     34,529.81     34,529.81     34,529.81
# 9                   PEDAGOGO  4,242,829.85  3,612,008.55  3,591,956.27
# 10               PRESIDÊNCIA          0.00     23,468.68          0.00
# 11              PROFESSOR(A) 70,409,060.36 54,729,492.83 54,542,162.66
# ...

# %%
occupations_quantitative_summary = categorical_payroll_summary(payroll_data, mode='quantitative', category='cargo')
occupations_quantitative_summary
# Out:
#                        CARGO  01-2025  02-2025  03-2025  04-2025  05-2025  \
# 0    AUXILIAR ADMINISTRATIVO       81       80       79       78       77
# 1       AUXILIAR EDUCACIONAL      105      105      102      100      100
# 2                   CUIDADOR      230      232      232      232      231
# 3                    DIRETOR      299      290      291      290      293
# 4   ESPECIALISTA EM EDUCAÇÃO      102       51       51       50       58
# 5                    GERENTE        1        2        2        0        0
# 6       GRATIFICAÇÃO DESTINO        0        0        6        0        0
# 7                  INSTRUTOR       12        6        6        6        5
# 8       INTERPRETE DE LIBRAS        7        7        7        7        6
# 9                   PEDAGOGO      706      454      450      447      452
# 10               PRESIDÊNCIA        0        1        0        0        0
# 11              PROFESSOR(A)    10485     5720     5689     5656     5660
# ...

# %%
occupation_summary = pd.merge(
    occupations_quantitative_summary[['CARGO', 'MEDIANA', 'MÉDIA', 'TOTAL']],
    occupations_financial_summary[['CARGO', 'MEDIANA', 'MÉDIA', 'TOTAL']],
    how='outer',
    on='CARGO',
    suffixes=['_QTD', '_R$']
)

table_occupations_summary = table_chart(
    occupation_summary,
    cell_format=[None]+[',.0f']*3+[',.2f']*3,
    cell_align=['center','right'],
    cell_fill_color=['white', '#F9FAFB']*7+['white', '#EFF6FF'],
    columnwidth=[2,1],
    cellheight=25,
    width=1200,
    height=440
)
table_occupations_summary.show()
table_occupations_summary.write_image('../2025/Dados_processados/imgs/folha/tabelas/cargos.png', width=1200, height=440)
# Out:
# WARNING	Thread(Thread-65 (run)) Task(Task-228) choreographer.browser_async:browser_async.py:_close()- Resorting to unclean kill browser.

# %%
data = occupation_summary.copy()
data = data.drop(labels=data.loc[data.CARGO=='TOTAL'].index,axis=0)
data = data.sort_values(by='TOTAL_R$')
data

h_bar_occupation_summary = h_bar_chart(
    x=data['TOTAL_R$'],
    y=data['CARGO'],
    title='Distribuição financeira por Cargo',
    width=1200,
    height=350
)
h_bar_occupation_summary.show()
h_bar_occupation_summary.write_image('../2025/Dados_processados/imgs/folha/h_bar_occupation_summary.png', width=1200, height=350)
# Out:
# WARNING	Thread(Thread-184 (run)) Task(Task-527) choreographer.browser_async:browser_async.py:_close()- Resorting to unclean kill browser.

# %% [markdown]
# ### Folha de Pagamento por Lotação

# %%
from payroll_utils import categorical_payroll_summary

workplaces_financial_summary = categorical_payroll_summary(payroll_data, mode='financial', category='lotação')
workplaces_financial_summary
# Out:
#                                                        LOTAÇÃO       01-2025  \
# 0                                         CENTROS EDUCACIONAIS  4,809,720.82
# 1                                                    CONSELHOS     13,736.71
# 2                                               COORDENADORIAS     10,045.29
# 3                                                      NUCLEOS    135,929.52
# 4                           POLO UNIVERSITARIO EQUADOR- MACAPA          0.00
# 5                                                   SECRETARIA     47,238.84
# 6                                                SEM DESCRIÇÃO  2,643,515.07
# 7      UNIDADE DE CONTROLE DE LOTACAO E MOVIMENTACAO - CEDIDOS      7,854.43
# 8   UNIDADE DE CONTROLE DE LOTACAO E MOVIMENTACAO - DISPOSICAO     45,118.50
# 9   UNIDADE DE CONTROLE DE LOTACAO E MOVIMENTACAO - TEMPORARIO     42,060.74
# 10                                             UNIDADE ESCOLAR 71,936,402.47
# ...

# %%
workplaces_quantitative_summary = categorical_payroll_summary(payroll_data, mode='quantitative', category='lotação')
workplaces_quantitative_summary
# Out:
#                                                        LOTAÇÃO  01-2025  \
# 0                                         CENTROS EDUCACIONAIS      727
# 1                                                    CONSELHOS        4
# 2                                               COORDENADORIAS        2
# 3                                                      NUCLEOS       32
# 4                           POLO UNIVERSITARIO EQUADOR- MACAPA        0
# 5                                                   SECRETARIA        5
# 6                                                SEM DESCRIÇÃO      296
# 7      UNIDADE DE CONTROLE DE LOTACAO E MOVIMENTACAO - CEDIDOS        2
# 8   UNIDADE DE CONTROLE DE LOTACAO E MOVIMENTACAO - DISPOSICAO       10
# 9   UNIDADE DE CONTROLE DE LOTACAO E MOVIMENTACAO - TEMPORARIO        6
# 10                                             UNIDADE ESCOLAR    10904
# 11           UNIDADE ESCOLAR MUNICIPAL - REGIME DE COLABORAÇÃO      460
# ...

# %%
workplace_summary = pd.merge(
    workplaces_quantitative_summary[['LOTAÇÃO', 'MEDIANA', 'MÉDIA', 'TOTAL']],
    workplaces_financial_summary[['LOTAÇÃO', 'MEDIANA', 'MÉDIA', 'TOTAL']],
    how='outer',
    on='LOTAÇÃO',
    suffixes=['_QTD', '_R$']
)

linha_total = workplace_summary.loc[workplace_summary['LOTAÇÃO']=='TOTAL']
workplace_summary = workplace_summary.drop(workplace_summary.loc[workplace_summary['LOTAÇÃO']=='TOTAL'].index)
workplace_summary = pd.concat(
    [
        workplace_summary,
        linha_total
    ]
)

table_workplace_summary = table_chart(
    workplace_summary,
    cell_format=[None]+[',.0f']*3+[',.2f']*3,
    cell_align=['center','right'],
    cell_fill_color=['white','#F9FAFB']*(int(len(workplace_summary)/2))+[ '#EFF6FF'],
    columnwidth=[4,1],
    cellheight=25,
    width=1200,
    height=420
)
table_workplace_summary.show()
table_workplace_summary.write_image('../2025/Dados_processados/imgs/folha/tabelas/lotções.png', width=1200, height=440)
# Out:
# WARNING	Thread(Thread-67 (run)) Task(Task-265) choreographer.browser_async:browser_async.py:_close()- Resorting to unclean kill browser.

# %%
data = workplace_summary.copy()
data = data.drop(labels=data.loc[data['LOTAÇÃO']=='TOTAL'].index,axis=0)
data = data.sort_values(by='TOTAL_R$')
data

h_bar_workplace_summary = h_bar_chart(
    x=data['TOTAL_R$'],
    y=data['LOTAÇÃO'],
    title='Distribuição Financeira por Lotação',
    width=1200,
    height=350
)
h_bar_workplace_summary.show()
h_bar_workplace_summary.write_image('../2025/Dados_processados/imgs/folha/h_bar_workplace_summary.png', width=1200, height=350)

# %% [markdown]
# ### Classificação de Cargos

# %%
from payroll_utils import dict_cargos, get_dataframe_occupatins


occupation_classificatory = get_dataframe_occupatins(dict_cargos)
occupation_classificatory.head(1)
# Out:
#        AUXILIAR ADMINISTRATIVO  AUXILIAR EDUCACIONAL  \
# 0  481026 - AGENTE DE PORTARIA  AUXILIAR EDUCACIONAL
#
#                                    CHEFIA  \
# 0  GERENTE ESPECIALISTA EM INFRAESTRUTURA
#
#                                             COORDENADOR  CUIDADOR  \
# 0  COORDENADOR DA COORDENADORIA DE EDUCACAO ESPECIFICAR  CUIDADOR
#
#                   DIRETOR  ESPECIALISTA EM EDUCAÇÃO        GERENTE  \
# 0  DIRETOR - TIPOLOGIA IV  ESPECIALISTA EM EDUCACAO  GERENTE GERAL
#
#    GRATIFICAÇÃO DESTINO                  INSTRUTOR  \
# 0  GRATIFICACAO DESTINO  INSTRUTOR MUSICAL A1-40HS
#
#          INTERPRETE DE LIBRAS  SEM DESCRIÇÃO  PEDAGOGO  \
# 0  INTERPRETE DE LIBRAS - 40H  SEM DESCRIÇÃO  PEDAGOGO
#
#                                                                              PRESIDÊNCIA  \
# 0  PRESIDENTE DO CONSELHO PERMANENTE DE VALORIZACAO DOS PROFISSIONAIS DA EDUCACAO BASICA
#
#     PROFESSOR(A)                        RESPONSÁVEL SECRETARIO ESCOLAR
# ...

# %% [markdown]
# ### Classificação de Lotações

# %%
from payroll_utils import dict_lotacao, get_dataframe_workplace


workplace_classificatory = get_dataframe_workplace(dict_lotacao)
workplace_classificatory.head(1)
# Out:
#                           COMISSÕES              CENTROS EDUCACIONAIS  \
# 0  COMISSAO PERMANENTE DE LICITACAO  CENTRO CULTURAL FRANCO AMAPAENSE
#
#                        CONSELHOS                  COORDENADORIAS  \
# 0  CONSELHO ESTADUAL DE EDUCACAO  COORDENADORIA DE ADMINISTRACAO
#
#                           GERÊNCIAS                      NUCLEOS  \
# 0  GERENCIA DE PROJETOS TEMPORARIOS  NUCLEO DE EDUCACAO INDIGENA
#
#    SEM DESCRIÇÃO  POLO INTERCAMBIO UNIVERSIDADE ABERTA DO BRASIL- OIAPOQUE  \
# 0  SEM DESCRIÇÃO  POLO INTERCAMBIO UNIVERSIDADE ABERTA DO BRASIL- OIAPOQUE
#
#    POLO UNIVERSITARIO EQUADOR- MACAPA SECRETARIA  \
# 0  POLO UNIVERSITARIO EQUADOR- MACAPA   GABINETE
#
#    UNIDADE DE CONTROLE DE LOTACAO E MOVIMENTACAO - CEDIDOS  \
# 0  UNIDADE DE CONTROLE DE LOTACAO E MOVIMENTACAO - CEDIDOS
#
#    UNIDADE DE CONTROLE DE LOTACAO E MOVIMENTACAO - DISPOSICAO  \
# 0  UNIDADE DE CONTROLE DE LOTACAO E MOVIMENTACAO - DISPOSICAO
#
# ...

# %% [markdown]
# ### Ajustes Mensais

# %%
from payroll_utils import get_adjust_data

adjust_data =  get_adjust_data(path='../2025/Dados_fonte/Folha_pagamento/Relatorios_Ajustes').reset_index()
adjust_data
# Out:
# DATA         CÓDIGO                                    DESCRIÇÃO     01-25  \
# 0     5.1.1.0105.00  DESCONTOS POR FALTA, PUNICAO OU INDENIZACAO 48,521.09
# 1     6.3.0.0000.00                  DESPESAS CORRENTES A ANULAR 13,374.19
# 2             TOTAL                                              61,895.28
#
# DATA     02-25     03-25     04-25     05-25     06-25      TOTAL
# 0    19,904.80 17,105.47 33,159.11 32,763.21 51,802.47 203,256.15
# 1    26,289.60 16,926.05 23,097.11 24,895.98 26,477.05 131,059.98
# 2    46,194.40 34,031.52 56,256.22 57,659.19 78,279.52 334,316.13

# %%
# ----------------------------
# Dados extraídos da sua tabela
# ----------------------------
a=budget_summary.iloc[2,2]
b=payroll_budget.loc[payroll_budget.Natureza=='319013 - Obrigações Patronais', 'Despesas Empenhadas'].values[0]
c=payroll_budget.loc[payroll_budget.Natureza=='319113 - Obrigações Patronais', 'Despesas Empenhadas'].values[0]
d=a-b-c
e=other_expenses_budget.loc[other_expenses_budget.Natureza=='339046 - Auxílio-Alimentação', 'Despesas Empenhadas'].values[0]
f=d+e
g=adjust_data.loc[adjust_data['CÓDIGO']=='5.1.1.0105.00', 'TOTAL'].values[0]
h=adjust_data.loc[adjust_data['CÓDIGO']=='6.3.0.0000.00', 'TOTAL'].values[0]
i=f+g+h
data = {
    "Descrição": [
        "(=) Despesa com Remuneração dos Profissionais da Educação Básica Com Encargos Patronais SIOPE/MAVS/SIAFE (Empenho)",
        "(-) 319013 - Obrigações Patronais (Empenho)",
        "(-) 319113 - Obrigações Patronais (Empenho)",
        "(=) Despesa com Remuneração dos Profissionais da Educação Básica Sem Encargos Patronais SIOPE/MAVS/SIAFE (Empenho)",
        "(+) 339046 - Auxílio-Alimentação (Classificado como Outras Despesas, mas faz parte da Folha de Pagamento)",
        "(=) Despesa Total com Remuneração dos Profissionais da Educação Básica Sem Encargos Patronais SIOPE/MAVS/SIAFE (Empenho)",
        "(+) 5.1.1.0105.00 DESCONTOS POR FALTA, PUNICAO OU INDENIZACAO",
        "(+) 6.3.0.0000.00 DESPESAS CORRENTES A ANULAR",
        "(=) Despesa Total Ajustada com Remuneração dos Profissionais da Educação Básica Sem Encargos Patronais SIOPE/MAVS/SIAFE (Empenho)",
    ],
    "Valor (R$)": [
        a,
        b,
        c,
        d,
        e,
        f,
        g,
        h,
        i
    ]
}

adjust_calc = pd.DataFrame(data)

table_adjust_calc = table_chart(
    adjust_calc,
    cell_fill_color=['#EFF6FF','white','#F9FAFB','#EFF6FF','white','#EFF6FF','white','#F9FAFB','#EFF6FF'],
    columnwidth=[10,3],
    cellheight=25,
    width=1200, 
    height=270)

table_adjust_calc.show()
table_adjust_calc.write_image('../2025/Dados_processados/imgs/folha/tabelas/calculo_valor_ajustado_siafe.png', width=1200, height=270)
# Out:
# WARNING	Thread(Thread-85 (run)) Task(Task-302) choreographer.browser_async:browser_async.py:_close()- Resorting to unclean kill browser.

# %%
adjust_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   CÓDIGO     3 non-null      object
#  1   DESCRIÇÃO  3 non-null      object
#  2   01-25      3 non-null      float64
#  3   02-25      3 non-null      float64
#  4   03-25      3 non-null      float64
#  5   04-25      3 non-null      float64
#  6   05-25      3 non-null      float64
#  7   06-25      3 non-null      float64
#  8   TOTAL      3 non-null      float64
# dtypes: float64(7), object(2)
# memory usage: 348.0+ bytes

# %% [markdown]
# # **VISUALIZATIONS**

# %% [markdown]
# ## EXTRATOS BANCÁRIOS

# %% [markdown]
# ### Movimentação financeira

# %%
saldo_inicial = bank_statement_summary.iloc[0,1]

card_saldo_inicial = card_chart(
    nome='Saldo Inicial', 
    subtexto='Em 01/01/2025', 
    valor=saldo_inicial,
    bg_color="#EFF6FF",
    icone_url="https://img.icons8.com/?size=100&id=7991&format=png&color=339AF0",
    )
card_saldo_inicial.show()

# %%
entradas = bank_statement_summary.iloc[2,1]

card_entradas = card_chart(
    nome='Entradas Financeiras', 
    subtexto='Até o bimestre', 
    valor=entradas,
    bg_color="#ECFDF5",
    icone_url="https://img.icons8.com/?size=100&id=82688&format=png&color=00B14A",
    )
card_entradas.show()

# %%
saidas = bank_statement_summary.iloc[-2,1]

card_saidas = card_chart(
    nome='Saídas Financeiras', 
    subtexto='Até o bimestre', 
    valor=saidas,
    bg_color="#FEF2F2",
    icone_url="https://img.icons8.com/?size=100&id=ShL9XvK5RNbg&format=png&color=A30101",
    )
card_saidas.show()

# %%
saldo_final = bank_statement_summary.iloc[-1,1]

card_saldo_final = card_chart(
    nome='Saldo Final', 
    subtexto='Até o bimestre', 
    valor=saldo_final,
    bg_color="#F5F3FF",
    icone_url="https://img.icons8.com/?size=100&id=7985&format=png&color=CC5DE8",
    )
card_saldo_final.show()

# %%
img_movimentacao_financeira = financial_transaction_chart(saldo_inicial, entradas, saidas, saldo_final)
img_movimentacao_financeira.show()

# %% [markdown]
# ### Entradas Financeiras

# %%
data = pd.Series(
    index = [
        'Repasses Impostos',
        'Repasses Comp União',
        'Rendimentos Financeiros',
        'Outras Entradas',
    ],
    data = [
        bank_statement_summary.iloc[4],
        bank_statement_summary.iloc[7], 
        bank_statement_summary.iloc[12], 
        bank_statement_summary.iloc[13]
        ]
)
data.sort_values(ascending=False, inplace=True)

labels = data.index
values = data.values

fig = donut_chart(
    title="Composição das Entradas Financeiras",
    labels=labels,
    values=values,
    margin=dict(t=140, b=0, l=0, r=0),
    width=600,
    height=350,
)

fig.add_annotation(
    text=f"<span><b>Entradas correntes</b><br>{bank_statement_summary.iloc[3]/bank_statement_summary.iloc[2]*100:.1f}%</span>",
    x=0.5, y=0.5,
    font=dict(family="Arial", color='#6183E4'),
    showarrow=False
)

fig.show()
# fig.write_image('../2025/Dados_processados/imgs/composição_entradas_financeiras.png', engine="kaleido", width=600, height=400)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27504\187297591.py in ?()
#      11         bank_statement_summary.iloc[12],
#      12         bank_statement_summary.iloc[13]
#      13         ]
#      14 )
# ---> 15 data.sort_values(ascending=False, inplace=True)
#      16
#      17 labels = data.index
#      18 values = data.values
#
# c:\Users\adria\anaconda3\envs\cacs_fundeb\Lib\site-packages\pandas\core\series.py in ?(self, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    3856         if key:
#    3857             values_to_sort = cast(Series, ensure_key_mapped(self, key))._values
#    3858         else:
#    3859             values_to_sort = self._values
# -> 3860         sorted_index = nargsort(values_to_sort, kind, bool(ascending), na_position)
#    3861
# ...

# %%
fig = v_bar_chart(
    title="Distribuição das Entradas Financeiras",
    x=labels,
    y=values,
    color='labels',
    width=600,
    height=350
    )

fig.add_annotation(
    text=f"<span><b>Total</b><br><u>R$ {data.sum():,.2f}</u></span>",
    x=2, y=570000000,
    font=dict(size=14, family="Arial"),
    showarrow=False
)

fig.add_annotation(
    text=f"<span style='font-size: 0.8em;'><b>Entradas Correntes</b><br>R$ {data.sum()-data.iloc[-1]:,.2f}</span>",
    x=2, y=440000000,
    font=dict(size=14, family="Arial"),
    showarrow=False
)

fig.show()
# fig.write_image('../2025/Dados_processados/imgs/distribuição_entradas_financeiras.png', engine="kaleido", width=600, height=400)

# %% [markdown]
# ### Repasses

# %%
# Dados não acumulados de rendimentos mensais
bar_labels = incomes_summary['TOTAL_REPASSES_LIQUIDO'].drop('TOTAL').index
bar_values = incomes_summary['TOTAL_REPASSES_LIQUIDO'].drop('TOTAL').values

fig = v_bar_chart(
    title="Repasse Líquido Mensal",
    x=bar_labels,
    y=bar_values,
    textposition='outside',
    width=1200,
    height=300,
    margin=dict(l=20, r=20, t=40, b=0)
    )

fig.show()
# fig.write_image('../2025/Dados_processados/imgs/repasse_total_liq_mensal.png', width=1200, height=300)

# %%
# Seleciona apenas as linhas que representam meses (exclui o TOTAL)
data = incomes_summary.drop('TOTAL', errors='ignore')
bar_labels = data.index
bar_values = data['TOTAL_REPASSES_LIQUIDO_ACUMULADO']

fig = v_bar_chart(
    title="Repasse Líquido Mensal Acumulado",
    x=bar_labels,
    y=bar_values,
    textposition='outside',
    width=1200,
    height=300
    )


fig.show()
# fig.write_image('../2025/Dados_processados/imgs/repasse_total_liq_mensal_acumulado.png', width=1200, height=300)
# Out:
# WARNING	Thread(Thread-61 (run)) Task(Task-153) choreographer.browser_async:browser_async.py:_close()- Resorting to unclean kill browser.

# %%
data = transfers_data.iloc[-1,:-1]
data = data[data != 0]
data.index = data.index.str.slice(2, )
# data['Rendimentos'] = bank_statement_summary.iloc[12]
# data['Outras Entradas'] = bank_statement_summary.iloc[13]
data.sort_values(ascending=True, inplace=True)

labels = data.index
values = data.values

fig = h_bar_chart(
    title="Distribuição dos Repasses Líquidos",
    y=labels,
    x=values,
    color='labels',
    margin=dict(t=50, b=10, l=100, r=0),
    width=600,
    height=600,
)

fig.show()
# fig.write_image('../2025/Dados_processados/imgs/dist_repasses.png', width=600, height=600)

# %%
fig = donut_chart(
    title="Composição dos Repasses Líquidos",
    labels=labels,
    values=values,
    margin=dict(l=10, r=10, t=50, b=10),
    width=600,
    height=600,
)

fig.show()
# fig.write_image('../2025/Dados_processados/imgs/comp_repasses.png', width=600, height=600)
# Out:
# WARNING	Thread(Thread-63 (run)) Task(Task-191) choreographer.browser_async:browser_async.py:_close()- Resorting to unclean kill browser.

# %%
data= transfers_data.drop(columns=['TOTAL'], errors='ignore')
data = data.iloc[:-1,:]
data.columns = data.columns.str.slice(2, )  # Remove the 'RE' prefix from the column names
data

fig = go.Figure()

for col in data.columns:
    fig.add_trace(go.Scatter(
        x=data.index,
        y=data[col],
        mode='lines+markers+text',
        name=col,
        text=[''] * (len(data) - 1) + [col],
        textposition='top center'
    ))

fig.update_layout(
    template="plotly_white",
    title="Repasses Líquidos Individuais do Fundo",
    title_x=0.5,
    showlegend=False,
    paper_bgcolor='#f5f6fa',
    plot_bgcolor='#f5f6fa',
    width=1200,
    height=600,
    margin=dict(t=50, b=30, l=10, r=10),
    font=dict(family="Arial", color="gray"),
)

fig.show()

# %% [markdown]
# ### Rendimentos

# %%
data = applications['VALOR']

fig = v_bar_chart(
    title="Rendimentos Financeiros Mensais",
    x=data.index.strftime('%m/%Y'),
    y=data,
    color='#57CEA7',
    textposition='outside',
    width=1200,
    height=300
    )


fig.show()
# fig.write_image('../2025/Dados_processados/imgs/rendimentos_mensais.png', width=1200, height=300)
# Out:
# WARNING	Thread(Thread-55 (run)) Task(Task-42) choreographer.browser_async:browser_async.py:_close()- Resorting to unclean kill browser.

# %%
fig = v_bar_chart(
    title="Rendimentos Financeiros Mensais Acumulados",
    x=data.index.strftime('%m/%Y'),
    y=data.cumsum(),
    color='#57CEA7',
    textposition='outside',
    width=1200,
    height=300
    )

fig.show()
# fig.write_image('../2025/Dados_processados/imgs/rendimentos_mensais_acumulados.png', width=1200, height=300)
# Out:
# WARNING	Thread(Thread-53 (run)) Task(Task-5) choreographer.browser_async:browser_async.py:_close()- Resorting to unclean kill browser.

# %% [markdown]
# ### Outras Entradas

# %%
data = pd.Series(
    index=[
            'Ordens Canc./Anu.',
            'Aj COTA DAF',
            'Aj Comp. União'
        ],
    data=[
            bank_statement_summary.iloc[14],
            bank_statement_summary.iloc[16], 
            bank_statement_summary.iloc[17],
        ]
)
data.sort_values(ascending=False, inplace=True)

labels = data.index
values = data.values

fig = donut_chart(
    title="Composição Outras Entradas",
    labels=labels,
    values=values,
    width=600,
    height=600
)

fig.show()
# fig.write_image('../2025/Dados_processados/imgs/composição_outras_entradas.png', width=600, height=600)
# Out:
# WARNING	Thread(Thread-94 (run)) Task(Task-268) choreographer.browser_async:browser_async.py:_close()- Resorting to unclean kill browser.

# %%
fig = v_bar_chart(
    title="Distribuição Outras Entradas",
    x=labels,
    y=values,
    color='labels',
    width=600,
    height=600
    )

fig.show()
# fig.write_image('../2025/Dados_processados/imgs/distribuição_outras_entradas.png', width=600, height=600)
# Out:
# WARNING	Thread(Thread-105 (run)) Task(Task-305) choreographer.browser_async:browser_async.py:_close()- Resorting to unclean kill browser.

# %% [markdown]
# ### Saídas Financeiras

# %%
data = pd.Series(
    index=[
        'Desp. Canceladas',
        'Ajustes-COTA DAF',
        'Ajustes-Comple. União',
        'Desp. Pagas'
        ],
    data=[
        -bank_statement_summary.iloc[18,1], 
        -bank_statement_summary.iloc[19,1], 
        -bank_statement_summary.iloc[20,1],
        -bank_statement_summary.iloc[21,1]]
    )
data.sort_values(ascending=False, inplace=True)

labels = data.index
values = data.values

fig = donut_chart(
    title="Composição das Saídas Financeiras",
    labels=labels,
    values=values,
    colors=["#BF20BF", '#FF9F43', '#F7B731', '#FF6B6B'],
    margin=dict(l=10, r=10, t=190, b=10),
    width=500,
    height=500,
)

fig.show()
# fig.write_image('../2025/Dados_processados/imgs/compo_saidas_financeira.png', width=600, height=350)

# %%
fig = v_bar_chart(
    title="Distribuição das Saídas Financeiras",
    x=labels,
    y=values,
    color=["#BF20BF", '#FF9F43', '#F7B731', '#FF6B6B'],
    width=600,
    height=350
    )

fig.add_annotation(
    text=f"<span><b>Total</b><br><u>R$ {data.sum():,.2f}</u></span>",
    x=2, y=450000000,
    font=dict(size=14, family="Arial"),
    showarrow=False
)

fig.show()
# fig.write_image('../2025/Dados_processados/imgs/dist_saidas_financeira.png', width=600, height=350)
# Out:
# WARNING	Thread(Thread-283 (run)) Task(Task-492) choreographer.browser_async:browser_async.py:_close()- Resorting to unclean kill browser.

# %% [markdown]
# ## CONTÁBIL

# %% [markdown]
# ## FOLHA DE PAGAMENTO

# %% [markdown]
# ## SIOPE

# %%
indicators_siope
# Out:
#                                                                        LIMITES OBRIGATÓRIOS DO FUNDEB  \
# 0                                 1. Mínimo de 70% - Remuneração dos Profissionais da Educação Básica
# 1                                 ....1.1. Exigido (70% excluídos complementações e seus rendimentos)
# 2                                               ....1.2. Aplicado após deduções (Despesas Liquidadas)
# 3                                                                 2. Máximo de 30%  - Outras Despesas
# 4                                     ....2.1. Exigido (30% excluídos complementação da união – VAAR)
# 5                                               ....2.2. Aplicado após deduções (despesas liquidadas)
# 6   3. Proporção de 50% - Complementação da União ao FUNDEB (VAAT) - Educação Infantil (EXCLUSIVO DF)
# 7                   4. Mínimo de 15% - Complementação da União ao FUNDEB (VAAT) - Despesas de Capital
# ...

# %%
indicator_70 = indicator_chart(
    tittle="Mínimo com Remuneração dos <br>Profissionais da Educação Básica Pública (70%)",
    subtittle='Até o bimestre',
    value=(indicators_siope.iloc[2,1]/indicators_siope.iloc[0,1])*100,
    delta_reference=70,
    color_up=True)

indicator_70.show()
# indicator_70.write_image('../2025/Dados_processados/imgs/siope/indicador_70.png', width=400, height=250)
# Out:
# WARNING	Thread(Thread-117 (run)) Task(Task-152) choreographer.browser_async:browser_async.py:_close()- Resorting to unclean kill browser.

# %%
indicator_30 = indicator_chart(
    tittle="Máximo com Outras Despesas (30%)",
    subtittle='Até o bimestre',
    value=(indicators_siope.iloc[5,1]/indicators_siope.iloc[3,1])*100,
    delta_reference=30,
    color_up=False)

indicator_30.show()
# indicator_30.write_image('../2025/Dados_processados/imgs/siope/indicador_30.png', width=400, height=250)
# Out:
# WARNING	Thread(Thread-119 (run)) Task(Task-188) choreographer.browser_async:browser_async.py:_close()- Resorting to unclean kill browser.

# %%
indicator_10 = indicator_chart(
    tittle="Máximo de Receitas Não Aplicadas (10%)",
    subtittle='Até o bimestre',
    value=(indicators_siope.iloc[-1,1]/indicators_siope.iloc[-3,1])*100,
    delta_reference=10,
    color_up=False)

indicator_10.show()
# indicator_10.write_image('../2025/Dados_processados/imgs/siope/indicador_10.png', width=400, height=250)
# Out:
# WARNING	Thread(Thread-121 (run)) Task(Task-225) choreographer.browser_async:browser_async.py:_close()- Resorting to unclean kill browser.

# %% [markdown]
# # **CONFRONTO DE INFORMAÇÕES**

# %% [markdown]
# ## Movimentação Financeira

# %%
comp_saldo_inicial = comparison_card_chart('Saldo Inicial', name1='Extrato', value1=bank_statement_summary.iloc[0,1], name2='SIOPE', value2=fin_df.iloc[0,1], length=4)
comp_saldo_inicial.show()
# comp_saldo_inicial.write_image('../2025/Dados_processados/imgs/comparativos/comp_saldo_inicial.png', width=300, height=120)
# Out:
# WARNING	Thread(Thread-57 (run)) Task(Task-80) choreographer.browser_async:browser_async.py:_close()- Resorting to unclean kill browser.

# %%
comp_entradas = comparison_card_chart('Entradas Financeiras Correntes', name1='Extrato', value1=bank_statement_summary.iloc[2,1], name2='SIOPE', value2=fin_df.iloc[1,1], length=4)
comp_entradas.show()
# comp_entradas.write_image('../2025/Dados_processados/imgs/comparativos/comp_entradas.png', width=300, height=120)
# Out:
# WARNING	Thread(Thread-59 (run)) Task(Task-117) choreographer.browser_async:browser_async.py:_close()- Resorting to unclean kill browser.

# %%
comp_saidas = comparison_card_chart('Saídas Financeiras Correntes', name1='Extrato', value1=bank_statement_summary.iloc[21,1], name2='SIOPE', value2=saidas_ajustada_siope, length=4)
comp_saidas.show()
# comp_saidas.write_image('../2025/Dados_processados/imgs/comparativos/comp_saidas.png', width=300, height=120)
# Out:
# WARNING	Thread(Thread-61 (run)) Task(Task-154) choreographer.browser_async:browser_async.py:_close()- Resorting to unclean kill browser.

# %%
comp_saldo_final = comparison_card_chart('Saldo Final', name1='Extrato', value1=round(bank_statement_summary.iloc[-1,1],2), name2='SIOPE', value2=saldo_final_ajustado_siope, length=4)
comp_saldo_final.show()
# comp_saldo_final.write_image('../2025/Dados_processados/imgs/comparativos/comp_saldo_final.png', width=300, height=120)
# Out:
# WARNING	Thread(Thread-63 (run)) Task(Task-191) choreographer.browser_async:browser_async.py:_close()- Resorting to unclean kill browser.

# %% [markdown]
# ## Entradas Financeiras

# %%
comp_repasses = comparison_card_chart('Repasses de Impostos', name1='Extrato', value1=bank_statement_summary.iloc[3,1], name2='SIOPE', value2=ingressos_df.iloc[1,1], length=3)
comp_repasses.show()
# comp_repasses.write_image('../2025/Dados_processados/imgs/comparativos/comp_repasses.png', width=400, height=120)
# Out:
# WARNING	Thread(Thread-69 (run)) Task(Task-374) choreographer.browser_async:browser_async.py:_close()- Resorting to unclean kill browser.

# %%
comp_complementacao_uniao = comparison_card_chart('Repasses de Complementação da União', name1='Extrato', value1=round(bank_statement_summary.iloc[6,1],2), name2='SIOPE', value2=ingressos_df.iloc[2,1], length=3)
comp_complementacao_uniao.show()
# comp_complementacao_uniao.write_image('../2025/Dados_processados/imgs/comparativos/comp_complementacao_uniao.png', width=400, height=120)
# Out:
# WARNING	Thread(Thread-73 (run)) Task(Task-411) choreographer.browser_async:browser_async.py:_close()- Resorting to unclean kill browser.

# %%
comp_rendimentos = comparison_card_chart('Rendimentos Financeiros', name1='Extrato', value1=round(bank_statement_summary.iloc[11,1],2), name2='SIOPE', value2=ingressos_df.iloc[-2,1], length=3)
comp_rendimentos.show()
# comp_rendimentos.write_image('../2025/Dados_processados/imgs/comparativos/comp_rendimentos.png', width=400, height=120)

# %% [markdown]
# ## Saídas Financeiras

# %% [markdown]
# ## Orçamento

# %% [markdown]
# ### Geral

# %%
comp_orcamento_dotacao = comparison_card_chart('Dotação Atualizada', name1='SIAFE', value1=budget_summary.iloc[1,4], name2='SIOPE', value2=dotacao_att, length=5)
comp_orcamento_dotacao.show()
# comp_orcamento_dotacao.write_image('../2025/Dados_processados/imgs/comparativos/comp_dot_att.png', width=240, height=120)
# Out:
# WARNING	Thread(Thread-198 (run)) Task(Task-118) choreographer.browser_async:browser_async.py:_close()- Resorting to unclean kill browser.

# %%
comp_desp_empenhadas = comparison_card_chart('Despesas Empenhadas', name1='SIAFE', value1=budget_summary.iloc[2,4], name2='SIOPE', value2=desp_empenhadas, length=5)
comp_desp_empenhadas.show()
# comp_desp_empenhadas.write_image('../2025/Dados_processados/imgs/comparativos/comp_desp_empenhadas.png', width=240, height=120)
# Out:
# WARNING	Thread(Thread-200 (run)) Task(Task-155) choreographer.browser_async:browser_async.py:_close()- Resorting to unclean kill browser.

# %%
comp_desp_liquidadas = comparison_card_chart('Despesas Liquidadas', name1='SIAFE', value1=budget_summary.iloc[3,4], name2='SIOPE', value2=desp_liquidadas, length=5)
comp_desp_liquidadas.show()
# comp_desp_liquidadas.write_image('../2025/Dados_processados/imgs/comparativos/comp_desp_liquidadas.png', width=240, height=120)
# Out:
# WARNING	Thread(Thread-202 (run)) Task(Task-192) choreographer.browser_async:browser_async.py:_close()- Resorting to unclean kill browser.

# %%
comp_desp_pagas = comparison_card_chart('Despesas do Exercício Pagas', name1='SIAFE', value1=budget_summary.iloc[4,4], name2='SIOPE', value2=desp_pagas, length=5)
comp_desp_pagas.show()
# comp_desp_pagas.write_image('../2025/Dados_processados/imgs/comparativos/comp_desp_pagas.png', width=240, height=120)
# Out:
# WARNING	Thread(Thread-204 (run)) Task(Task-229) choreographer.browser_async:browser_async.py:_close()- Resorting to unclean kill browser.

# %%
comp_desp_rap = comparison_card_chart('Restos a Pagar Quitados', name1='SIAFE', value1=budget_summary.iloc[5,4], name2='SIOPE', value2=desp_rap, length=5)
comp_desp_rap.show()
# comp_desp_rap.write_image('../2025/Dados_processados/imgs/comparativos/comp_rap_quitados.png', width=240, height=120)
# Out:
# WARNING	Thread(Thread-208 (run)) Task(Task-303) choreographer.browser_async:browser_async.py:_close()- Resorting to unclean kill browser.

# %% [markdown]
# ### 70%

# %%
comp_orcamento_dotacao_70 = comparison_card_chart('Dotação Atualizada (Min. 70%)', name1='SIAFE', value1=budget_summary.iloc[1,2], name2='SIOPE', value2=dotacao_att_fol_pag, length=5)
comp_orcamento_dotacao_70.show()
# comp_orcamento_dotacao_70.write_image('../2025/Dados_processados/imgs/comparativos/comp_dot_att_70.png', width=240, height=120)

# %%
comp_desp_empenhadas_70 = comparison_card_chart('Despesas Empenhadas (Min. 70%)', name1='SIAFE', value1=budget_summary.iloc[2,2], name2='SIOPE', value2=desp_empenhadas_fol_pag, length=5)
comp_desp_empenhadas_70.show()
# comp_desp_empenhadas_70.write_image('../2025/Dados_processados/imgs/comparativos/desp_empenhadas_70.png', width=240, height=120)

# %%
comp_desp_liquidadas_70 = comparison_card_chart('Despesas Liquidadas (Min. 70%)', name1='SIAFE', value1=budget_summary.iloc[3,2], name2='SIOPE', value2=desp_liquidadas_fol_pag, length=5)
comp_desp_liquidadas_70.show()
# comp_desp_liquidadas_70.write_image('../2025/Dados_processados/imgs/comparativos/desp_liquidadas_70.png', width=240, height=120)
# Out:
# WARNING	Thread(Thread-117 (run)) Task(Task-303) choreographer.browser_async:browser_async.py:_close()- Resorting to unclean kill browser.

# %%
comp_desp_pagas_70 = comparison_card_chart('Despesas Pagas (Min. 70%)', name1='SIAFE', value1=budget_summary.iloc[4,2], name2='SIOPE', value2=desp_pagas_fol_pag, length=5)
comp_desp_pagas_70.show()
# comp_desp_pagas_70.write_image('../2025/Dados_processados/imgs/comparativos/desp_pagas_70.png', width=240, height=120)
# Out:
# WARNING	Thread(Thread-119 (run)) Task(Task-340) choreographer.browser_async:browser_async.py:_close()- Resorting to unclean kill browser.

# %%
comp_desp_rap_70 = comparison_card_chart('Restos a Pagar Quitados (Min. 70%)', name1='SIAFE', value1=budget_summary.iloc[5,2], name2='SIOPE', value2=desp_rap_fol_pag, length=5)
comp_desp_rap_70.show()
# comp_desp_rap_70.write_image('../2025/Dados_processados/imgs/comparativos/comp_rap_quitados_70.png', width=240, height=120)

# %% [markdown]
# ### 30%

# %%
comp_orcamento_dotacao_30 = comparison_card_chart('Dotação Atualizada (Max. 30%)', name1='SIAFE', value1=budget_summary.iloc[1,3], name2='SIOPE', value2=dotacao_att_out_desp, length=5)
comp_orcamento_dotacao_30.show()
# comp_orcamento_dotacao_30.write_image('../2025/Dados_processados/imgs/comparativos/comp_dot_att_30.png', width=240, height=120)

# %%
comp_desp_empenhadas_30 = comparison_card_chart('Despesas Empenhadas (Max. 30%)', name1='SIAFE', value1=budget_summary.iloc[2,3], name2='SIOPE', value2=desp_empenhadas_out_desp, length=5)
comp_desp_empenhadas_30.show()
# comp_desp_empenhadas_30.write_image('../2025/Dados_processados/imgs/comparativos/comp_desp_empenhadas_30.png', width=240, height=120)
# Out:
# WARNING	Thread(Thread-144 (run)) Task(Task-487) choreographer.browser_async:browser_async.py:_close()- Resorting to unclean kill browser.

# %%
comp_desp_liquidadas_30 = comparison_card_chart('Despesas Liquidadas (Max. 30%)', name1='SIAFE', value1=budget_summary.iloc[3,3], name2='SIOPE', value2=desp_liquidadas_out_desp, length=5)
comp_desp_liquidadas_30.show()
# comp_desp_liquidadas_30.write_image('../2025/Dados_processados/imgs/comparativos/comp_desp_liquidadas_30.png', width=240, height=120)
# Out:
# WARNING	Thread(Thread-147 (run)) Task(Task-524) choreographer.browser_async:browser_async.py:_close()- Resorting to unclean kill browser.

# %%
comp_desp_pagas_30 = comparison_card_chart('Despesas do Exercício Pagas (Max. 30%)', name1='SIAFE', value1=budget_summary.iloc[4,3], name2='SIOPE', value2=desp_pagas_out_desp, length=5)
comp_desp_pagas_30.show()
# comp_desp_pagas_30.write_image('../2025/Dados_processados/imgs/comparativos/comp_desp_pagas_30.png', width=240, height=120)
# Out:
# WARNING	Thread(Thread-151 (run)) Task(Task-599) choreographer.browser_async:browser_async.py:_close()- Resorting to unclean kill browser.

# %%
comp_desp_rap_30 = comparison_card_chart('Restos a Pagar Quitados (Max. 30%)', name1='SIAFE', value1=budget_summary.iloc[5,3], name2='SIOPE', value2=desp_rap_out_desp, length=5)
comp_desp_rap_30.show()
# comp_desp_rap_30.write_image('../2025/Dados_processados/imgs/comparativos/comp_rap_quitados_30.png', width=240, height=120)

# %% [markdown]
# ## Folha

# %%
comp_folha = comparison_card_chart('Folha de Pagamento', name1='SIGRH', value1=monthly_summary.iloc[-1,-1], name2='SIAFE/SIOPE', value2=adjust_calc.iloc[-1,-1], length=1)
comp_folha.show()
comp_folha.write_image('../2025/Dados_processados/imgs/comparativos/comp_folha.png', width=1200, height=120)
# Out:
# WARNING	Thread(Thread-285 (run)) Task(Task-786) choreographer.browser_async:browser_async.py:_close()- Resorting to unclean kill browser.

# %% [markdown]
# # **FILES**

# %% [markdown]
# ## EXTRATOS BANCÁRIOS

# %%
with pd.ExcelWriter('../2025/Dados_processados/Extratos_Consolidados.xlsx') as writer:
    consolidation_banks_data.to_excel(writer, sheet_name='Dados Consolidados')
    financial_sumary.to_excel(writer, sheet_name='Resumo Financeiro')
    bank_statement_summary.to_excel(writer, sheet_name='Relatório Geral')
    ins_bank.to_excel(writer, sheet_name='Detalhamento Entradas')
    outs_bank.to_excel(writer, sheet_name='Detalhamento Saídas')
    applications.to_excel(writer, sheet_name='Detalhamento Rendimentos')
    transfers_data.to_excel(writer, sheet_name='Dados Transferências')
    transfers_adjust_data.to_excel(writer, sheet_name='Dados Ajustes Transferências')
    incomes_summary.to_excel(writer, sheet_name='Resumo Transferências')
    res_consolidation_data.to_excel(writer, sheet_name='Dados REs')
    res_canceled.to_excel(writer, sheet_name='REs Canceladas')

# %% [markdown]
# ## CONTÁBIL

# %%
with pd.ExcelWriter('../2025/Dados_processados/Contabilidade_Orçamento.xlsx') as writer:
    accounting_data.to_excel(writer, sheet_name='Dados_Consolidados')
    monthly_accounting_payments_data.to_excel(writer, sheet_name='Dados_Pgtos_Contábeis_Mensais')
    budget_summary.to_excel(writer, sheet_name='Relatório_Orçamentário')
    accounting_summary.to_excel(writer, sheet_name='Relatório_Contábil_Geral')
    payroll_budget.to_excel(writer, sheet_name='Resumo_Contábil_Folha_Pagamento')
    other_expenses_budget.to_excel(writer, sheet_name='Resumo_Contábil_Outras_Despesas')
    paid_cases.to_excel(writer, sheet_name='Processos_Outras_Despesas_Pagos')

# %% [markdown]
# ## FOLHA

# %%
with pd.ExcelWriter(f'../{year}/Dados_processados/Folha_Pagamento_Consolidada.xlsx') as writer:
    payroll_data.to_excel(writer, sheet_name='Dados_Consolidados', index=False)
    payroll_summary.to_excel(writer, sheet_name='Resumo_Por_Folha')
    monthly_summary.to_excel(writer, sheet_name='Resumo_Mensal')
    occupations_financial_summary.to_excel(writer, sheet_name='Detalhamento_Valores_Cargos')
    occupations_quantitative_summary.to_excel(writer, sheet_name='Detalhamento_Qtd_Cargos')
    occupation_classificatory.to_excel(writer, sheet_name='Classificação_Cargos')
    workplaces_financial_summary.to_excel(writer, sheet_name='Detalhamento_Valores_Lotações')
    workplaces_quantitative_summary.to_excel(writer, sheet_name='Detalhamento_Qtd_Lotações')
    workplace_classificatory.to_excel(writer, sheet_name='Classificações_Lotações')
    adjust_data.to_excel(writer, sheet_name='Detalhamento_Ajustes_Folha')

# %% [markdown]
# ## VISUALIZAÇÕES
